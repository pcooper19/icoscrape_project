# %%
import requests
from bs4 import BeautifulSoup
from bs4.diagnose import diagnose
import pandas


r = requests.get("https://icodrops.com")
c = r.content

# %%
# Settings for notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Show Python version
import platform
platform.python_version()
# Out:
# '3.6.3'

# %%
soup = BeautifulSoup(c, "html.parser")

# %%
print (soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html id="admin" lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
# <meta content="summary" name="twitter:card">
# <meta content="@ICODrops" name="twitter:site">
# <meta content="ICO Drops" name="twitter:title"/>
# <meta content="The Simple ICO List." name="twitter:description"/>
# <meta content="http://icodrops.com/wp-content/uploads/2017/08/cropped-Group.png" name="twitter:image"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://icodrops.com/wp-content/cache/autoptimize/css/autoptimize_a51c25a5ff72fb2560f9fcb67f8b779d.css" media="all" rel="stylesheet" type="text/css"><title>ICO Drops - Calendar of active and upcoming ICO. Complete list with Token Sales</title>
# <!-- This site is optimized with the Yoast SEO Premium plugin v5.9.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content='ICO Drops contains a complete list of all ICOs (Initial Coin Offerings) in three columns "Active ICO", "Upcoming ICO", "Ended ICO" with rating and analysis.' name="description"/>
# <link href="https://icodrops.com/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="ICO Drops - Calendar of active and upcoming ICO. Complete list with Token Sales" property="og:title"/>
# <meta content='ICO Drops contains a complete list of all ICOs (Initial Coin Offerings) in three columns "Active ICO", "Upcoming ICO", "Ended ICO" with rating and analysis.' property="og:description"/>
# <meta content="https://icodrops.com/" property="og:url"/>
# <meta content="ICO Drops" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content='ICO Drops contains a complete list of all ICOs (Initial Coin Offerings) in three columns "Active ICO", "Upcoming ICO", "Ended ICO" with rating and analysis.' name="twitter:description"/>
# <meta content="ICO Drops - Calendar of active and upcoming ICO. Complete list with Token Sales" name="twitter:title"/>
# <meta content="@ICODrops" name="twitter:site"/>
# <meta content="@ICODrops" name="twitter:creator"/>
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"WebSite","@id":"#website","url":"https:\/\/icodrops.com\/","name":"ICO Drops","potentialAction":{"@type":"SearchAction","target":"https:\/\/icodrops.com\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <meta content="Q4FJ5E8SsFd2lqpm9RhwZSC52UPVVrDBwDuNtAGoTpk" name="google-site-verification"/>
# <!-- / Yoast SEO Premium plugin. -->
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://icodrops.com/feed/" rel="alternate" title="ICO Drops » Feed" type="application/rss+xml"/>
# <link href="https://icodrops.com/comments/feed/" rel="alternate" title="ICO Drops » Comments Feed" type="application/rss+xml"/>
# <script src="https://cdn.icodrops.com/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript"></script>
# <link href="https://icodrops.com/wp-json/" rel="https://api.w.org/"/>
# <link href="https://icodrops.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://cdn.icodrops.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://icodrops.com/" rel="shortlink"/>
# <link href="https://icodrops.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ficodrops.com%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://icodrops.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ficodrops.com%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link href="https://cdn.icodrops.com/wp-content/uploads/2017/08/cropped-Group-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://cdn.icodrops.com/wp-content/uploads/2017/08/cropped-Group-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://cdn.icodrops.com/wp-content/uploads/2017/08/cropped-Group-180x180.png" rel="apple-touch-icon-precomposed"/>
# <meta content="https://cdn.icodrops.com/wp-content/uploads/2017/08/cropped-Group-270x270.png" name="msapplication-TileImage"/>
# </link></meta></meta></head>
# <body class="home page-template-default page page-id-7 wp-custom-logo">
# <div class="site" id="page">
# <header class="site-header" id="masthead">
# <div><div class="textwidget custom-html-widget"><div class="the-top-banner text-center" style="background-color: #000; box-shadow: none;">
# <div>
# <a href="https://t.me/joinchat/FoisO0k4-XXBkPEikfdgow" rel="nofollow" target="_blank">
# <img alt="the-top" class="ad-logo" src="http://dev.icodrops.com/wp-content/uploads/2017/08/Vector.png" style="height: 30px;"/>
# </a>
# <div class="the-top-banner-text">
# <span class="ad-description" style="color:#fff;">Our First Official EN Telegram! Please, read the rules and you are welcome to chat!</span>
# <span>
# <a href="https://t.me/joinchat/FoisO0k4-XXBkPEikfdgow" rel="nofollow" style="vertical-align: 2px;" target="_blank">Chat Now</a>
# </span>
# </div>
# </div>
# </div></div></div> <div class="white-desk" id="ico-header">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <nav class="main-navigation" id="site-navigation">
# <div class="menu-left-container"><ul class="menu" id="ico-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10414" id="menu-item-10414"><a href="https://icodrops.com/ico-stats/">ICO STATS</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1030" id="menu-item-1030"><a href="https://icodrops.com/bounty-list/">BOUNTY</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7545" id="menu-item-7545"><a href="https://icodrops.com/category/ended-ico/">ENDED ICO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7546" id="menu-item-7546"><a href="https://icodrops.com/category/upcoming-ico/">UPCOMING ICO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7547" id="menu-item-7547"><a href="https://icodrops.com/category/active-ico/">ACTIVE ICO</a></li>
# </ul></div>
# <div>
# <a href="/" id="logo-a" itemprop="url" rel="home"><img alt="ICO Drops - Calendar of active and upcoming ICO" id="ico-header-logo" src="/wp-content/uploads/2017/09/LogoDrops.png"/></a>
# <div id="closebtn">close</div>
# <div id="menubtn">Menu</div>
# <div id="sm-search-icon"><img src="/wp-content/themes/ico-drops-2-0/img/Search.svg"/></div>
# <button aria-controls="ico-menu" aria-expanded="false" class="menu-toggle nav-toggle" id="nav-toogle-button"><span></span></button>
# <div class="search sm-hidden" id="search">
# <span>
# <img src="/wp-content/themes/ico-drops-2-0/img/Search.svg"/>
# </span>
# <span>
# <div class="">
# <form action="https://icodrops.com/" id="searchform" method="get" role="search">
# <input id="s" name="s" placeholder="Search ICO" type="text" value=""/>
# <input id="searchsubmit" type="submit" value="OK"/>
# </form>
# </div>
# </span>
# </div>
# </div>
# </nav><!-- #site-navigation -->
# </div>
# </div>
# </div><!-- container -->
# </div><!-- #ico-header -->
# </header><!-- #masthead -->
# <div class="site-content" id="content">
# <div class="content-area" id="primary">
# <main class="site-main" id="main">
# <div class="container">
# <article class="post-7 page type-page status-publish hentry" id="post-7">
# <div class="row">
# <!-- hmjim start -->
# <div class="valute col-12">
# <div class="disclamer">
# <div class="textwidget custom-html-widget"><div id="dscl"><div><span class="red">*</span> DISCLAIMER: All information including our "Interest Level" rating, is provided merely for informational purposes. ICO Drops does not provide investment advice (<a href="/disclaimer/" rel="nofollow" target="_blank">read more</a>).</div></div></div> </div>
# <div class="latest_post_home">
# <div class="soc_wrap">
# <div class="widget_text soc_link"><div class="textwidget custom-html-widget"><span class="telega">
# <a href="https://t.me/icodrops" target="_blank">TELEGRAM</a>
# <span class="soc_count">(7.6K+)</span>
# </span>
# <span class="twitter">
# <a href="https://twitter.com/ICODrops" target="_black">TWITTER</a>
# <span class="soc_count">(9K+)</span>
# </span></div></div> </div>
# </div>
# </div>
# <!-- hmjim end -->
# <div class="col-12 col-lg-4">
# <div class="category-table-header">
# <h2><a href="https://icodrops.com/category/active-ico/">ACTIVE ICO<sup class="blue">34</sup></a></h2>
# </div>
# <div class="ajax_content1" id="ajaxy">
# <div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="13909" href="https://icodrops.com/hoqu/" id="ccc" rel="bookmark">
# <img alt="Hoqu logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Slice-3-150x150.png" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"> </img></a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/hoqu/" rel="bookmark">HOQU</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Marketing</div>
# <div class="goal-in-card">
# <span class="green">
# 	$16,467,281	</span>
# 	/ $14,800,000 <span class="wat">111%</span> </div>
# <div class="categ_desc_short">HOQU is the first decentralized...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Marketing</div>
# <div id="new_column_categ_invisted">
# <span>$16,467,281</span> <span class="prec">111%</span>
# </div>
# <div id="categ_desctop">
# 							$14,800,000
# 			</div>
# <div class="date">
# 		48d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Signature BT, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: 40% on Pre-sale, up to 20% on Main-sale" title="BONUS: 40% on Pre-sale, up to 20% on Main-sale"></div></div>
# </div><div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="20945" href="https://icodrops.com/crowd-genie/" id="ccc" rel="bookmark">
# <img alt="Genie ICO logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/JATlRgvf_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"> </img></a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/crowd-genie/" rel="bookmark">Crowd Genie</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Finance</div>
# <div class="goal-in-card">
# 				 GOAL: $26,100,000				</div>
# <div class="categ_desc_short">Licensed and operational lending...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Finance</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$26,100,000
# 			</div>
# <div class="date">
# 		49d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA" title="Can’t participate: USA"></div><div class="categ_four yes tooltip" rel="Review" title="BOUNTY: Review"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 50% bonus" title="BONUS: Up to 50% bonus"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="23805" href="https://icodrops.com/pre/apex/" id="ccc" rel="bookmark">
# <div class="pre-icon">PRE SALE</div> <img alt="Apex logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/Apex-logo-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"> </img></a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/pre/apex/" rel="bookmark">APEX Pre-sale</a>
# </h3>
# <div class="ico-category-name">Blockchain Service</div>
# <div class="goal-in-card">
# 				 GOAL: $4,000,000				</div>
# <div class="categ_desc_short">APEX passes value and data...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Blockchain Service</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$4,000,000
# 			</div>
# <div class="date">
# 		12h left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (12/20 — 12/21)" title="Whitelist: YES (12/20 — 12/21)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: 20% during the pre-sale" title="BONUS: 20% during the pre-sale"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="9319" href="https://icodrops.com/swissborg/" id="ccc" rel="bookmark">
# <img alt="SwissBorg" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/SwissBorg-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"> </img></a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/swissborg/" rel="bookmark">SwissBorg</a>
# </h3>
# <div class="ico-category-name">Banking</div>
# <div class="goal-in-card">
# <span class="green">
# 	$23,310,000	</span>
# 	/ $25,200,000 <span class="wat">93%</span> </div>
# <div class="categ_desc_short">The SwissBorg project aims...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Banking</div>
# <div id="new_column_categ_invisted">
# <span>$23,310,000</span> <span class="prec">93%</span>
# </div>
# <div id="categ_desctop">
# 							$25,200,000
# 			</div>
# <div class="date">
# 		14h left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Following"></div><div class="categ_five no tooltip" rel="BONUS: NO INFORMATION" title="BONUS: NO INFORMATION"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="22429" href="https://icodrops.com/block-array/" id="ccc" rel="bookmark">
# <img alt="Block.array logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/Block.array-logo-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/block-array/" rel="bookmark">Block.array</a>
# </h3>
# <div class="ico-category-name">Blockchain Service</div>
# <div class="goal-in-card">
# <span class="green">
# 	$5,173,000	</span>
# 	/ $8,100,000 <span class="wat">64%</span> </div>
# <div class="categ_desc_short">Supply Chain Management &amp;...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Blockchain Service</div>
# <div id="new_column_categ_invisted">
# <span>$5,173,000</span> <span class="prec">64%</span>
# </div>
# <div id="categ_desctop">
# 							$8,100,000
# 			</div>
# <div class="date">
# 		4d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two yes tooltip" rel="Can’t participate: Singapore, China, Korea, Hong Kong" title="Can’t participate: Singapore, China, Korea, Hong Kong"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 35%" title="BONUS: Up to 35%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="11844" href="https://icodrops.com/envion/" id="ccc" rel="bookmark">
# <img alt="Envion Logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/okWAudN-_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/envion/" rel="bookmark">Envion</a>
# </h3>
# <div class="ico-category-name">Mining</div>
# <div class="goal-in-card">
# <span class="green">
# 	$56,397,091	</span>
# 	/ $150,000,000 <span class="wat">38%</span> </div>
# <div class="categ_desc_short">Highly profitable, global...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Mining</div>
# <div id="new_column_categ_invisted">
# <span>$56,397,091</span> <span class="prec">38%</span>
# </div>
# <div id="categ_desctop">
# 							$150,000,000
# 			</div>
# <div class="date">
# 		5d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="NO RESTRICTIONS" title="NO RESTRICTIONS"></div><div class="categ_four yes tooltip" rel="Translate, Review, Signature BT, Following" title="BOUNTY: Translate, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 30%" title="BONUS: Up to 30%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="22770" href="https://icodrops.com/elastos/" id="ccc" rel="bookmark">
# <img alt="Elastos logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/Elastos-logo-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/elastos/" rel="bookmark">Elastos</a>
# </h3>
# <div class="ico-category-name">Blockchain</div>
# <div class="goal-in-card">
# <span class="green">
# 	$57,891,200	</span>
# 	/ $94,100,000 <span class="wat">62%</span> </div>
# <div class="categ_desc_short">New blockchain whith totally...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Blockchain</div>
# <div id="new_column_categ_invisted">
# <span>$57,891,200</span> <span class="prec">62%</span>
# </div>
# <div id="categ_desctop">
# 							$94,100,000
# 			</div>
# <div class="date">
# 		22d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (UNTIL 01/04)" title="Whitelist: YES (UNTIL 01/04)"></div><div class="categ_two yes tooltip" rel="Can’t participate: China" title="Can’t participate: China"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five no tooltip" rel="BONUS: NO INFORMATION" title="BONUS: NO INFORMATION"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="19057" href="https://icodrops.com/pre/fortknoxster-pre-sale/" id="ccc" rel="bookmark">
# <div class="pre-icon">PRE SALE</div> <img alt="FortKnoxster" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/FortKnoxster-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/pre/fortknoxster-pre-sale/" rel="bookmark">FortKnoxster Pre-sale</a>
# </h3>
# <div class="ico-category-name">Mobile</div>
# <div class="goal-in-card">
# 				 GOAL: $15,000,000				</div>
# <div class="categ_desc_short">FortKnoxster offers end-to-end...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Mobile</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$15,000,000
# 			</div>
# <div class="date">
# 		26d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA, Singapore" title="Can’t participate: USA, Singapore"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Signature BT, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 50% bonus on Pre-sale" title="BONUS: Up to 50% bonus on Pre-sale"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="14359" href="https://icodrops.com/lala-world/" id="ccc" rel="bookmark">
# <img alt="Lala world" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Lala-world-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/lala-world/" rel="bookmark">LALA World</a>
# </h3>
# <div class="ico-category-name">Finance</div>
# <div class="goal-in-card">
# 				 GOAL: $19,600,000				</div>
# <div class="categ_desc_short">An Ecosystem for migrants...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Finance</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$19,600,000
# 			</div>
# <div class="date">
# 		27d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three no tooltip" rel="Whitelist: NO" title="Whitelist: NO"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA, China" title="Can’t participate: USA, China"></div><div class="categ_four yes tooltip" rel="Referrals, Sharing, Translate, Guest Post, Review, Signature BT, Following, Airdrop" title="BOUNTY: Referrals, Sharing, Translate, Guest Post, Review, Signature BT, Following, Airdrop"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 40%" title="BONUS: Up to 40%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="838" href="https://icodrops.com/bankera/" id="ccc" rel="bookmark">
# <img alt="Bankera Logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/08/q8wup7Tl_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/bankera/" rel="bookmark">Bankera</a>
# </h3>
# <div class="ico-category-name">Banking</div>
# <div class="goal-in-card">
# <span class="green">
# 	$63,461,105	</span>
# 	/ $208,500,000 <span class="wat">30%</span> </div>
# <div class="categ_desc_short">Bankera is building a digital...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Banking</div>
# <div id="new_column_categ_invisted">
# <span>$63,461,105</span> <span class="prec">30%</span>
# </div>
# <div id="categ_desctop">
# 							$208,500,000
# 			</div>
# <div class="date">
# 		49d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO" title="Whitelist: NO"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Referrals" title="BOUNTY: Referrals"></div><div class="categ_five no tooltip" rel="BONUS: NO INFORMATION" title="BONUS: NO INFORMATION"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="9294" href="https://icodrops.com/latium/" id="ccc" rel="bookmark">
# <img alt="" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Latium-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/latium/" rel="bookmark">Latium</a>
# </h3>
# <div class="ico-category-name">Collaboration</div>
# <div class="goal-in-card">
# <span class="green">
# 	$11,326,110	</span>
# 	/ $15,000,000 <span class="wat">76%</span> </div>
# <div class="categ_desc_short">Tasking platform with an AI-based...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Collaboration</div>
# <div id="new_column_categ_invisted">
# <span>$11,326,110</span> <span class="prec">76%</span>
# </div>
# <div id="categ_desctop">
# 							$15,000,000
# 			</div>
# <div class="date">
# 		50d left		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (UNTIL 11/28)" title="Whitelist: YES (UNTIL 11/28)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Referrals, Sharing, Translate, Signature BT, Following" title="BOUNTY: Referrals, Sharing, Translate, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 10%" title="BONUS: Up to 10%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="1962" href="https://icodrops.com/mobius/" id="ccc" rel="bookmark">
# <img alt="Mobius Logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/09/20430162_1727395694230442_1099940260472023494_n-150x150.png" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/mobius/" rel="bookmark">Mobius</a>
# </h3>
# <div class="ico-category-name">Blockchain Service</div>
# <div class="goal-in-card">
# <span class="green">
# 	$30,000,000	</span>
# 	/ $39,000,000 <span class="wat">77%</span> </div>
# <div class="categ_desc_short">Mobius closes the gap between...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Blockchain Service</div>
# <div id="new_column_categ_invisted">
# <span>$30,000,000</span> <span class="prec">77%</span>
# </div>
# <div id="categ_desctop">
# 							$39,000,000
# 			</div>
# <div class="date">
# 		DATE: TBA		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Translate, Guest Post, Following" title="BOUNTY: Translate, Guest Post, Following"></div><div class="categ_five no tooltip" rel="BONUS: NO INFORMATION" title="BONUS: NO INFORMATION"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="16987" href="https://icodrops.com/iungo/" id="ccc" rel="bookmark">
# <img alt="iungo logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/DSIkJuEr_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/iungo/" rel="bookmark">iungo</a>
# </h3>
# <div class="ico-category-name">Mobile</div>
# <div class="goal-in-card">
# <span class="green">
# 	$2,913,321	</span>
# 	/ $18,100,000 <span class="wat">16%</span> </div>
# <div class="categ_desc_short">Decentralised Global Wireless...</div> </div>
# </div>
# <div class="interest">
# <div class="nr">Not Rated</div> </div>
# <div class="categ_type">Mobile</div>
# <div id="new_column_categ_invisted">
# <span>$2,913,321</span> <span class="prec">16%</span>
# </div>
# <div id="categ_desctop">
# 							$18,100,000
# 			</div>
# <div class="date">
# 		1d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 50%" title="BONUS: Up to 50%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="2498" href="https://icodrops.com/pareto/" id="ccc" rel="bookmark">
# <img alt="Pareto Network Logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/10/Pareto-Logo-150x150.jpeg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/pareto/" rel="bookmark">PARETO</a>
# </h3>
# <div class="ico-category-name">Media</div>
# <div class="goal-in-card">
# 				 GOAL: $12,000,000				</div>
# <div class="categ_desc_short">The Pareto Network is the...</div> </div>
# </div>
# <div class="interest">
# <div class="nr">Not Rated</div> </div>
# <div class="categ_type">Media</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$12,000,000
# 			</div>
# <div class="date">
# 		5d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 20%" title="BONUS: Up to 20%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="2189" href="https://icodrops.com/srg/" id="ccc" rel="bookmark">
# <img alt="SRG Logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/09/SRG-Logo-150x150.png" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/srg/" rel="bookmark">SRG</a>
# </h3>
# <div class="ico-category-name">Gaming</div>
# <div class="goal-in-card">
# <span class="green">
# 	$1,046,691	</span>
# 	/ $15,000,000 <span class="wat">7%</span> </div>
# <div class="categ_desc_short">SRG - a decentralized loyalty...</div> </div>
# </div>
# <div class="interest">
# <div class="nr">Not Rated</div> </div>
# <div class="categ_type">Gaming</div>
# <div id="new_column_categ_invisted">
# <span>$1,046,691</span> <span class="prec">7%</span>
# </div>
# <div id="categ_desctop">
# 							$15,000,000
# 			</div>
# <div class="date">
# 		6d left		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA" title="Can’t participate: USA"></div><div class="categ_four yes tooltip" rel="BOUNTY: YES" title="BOUNTY: YES"></div><div class="categ_five yes tooltip" rel="BONUS: 5-25%" title="BONUS: 5-25%"></div></div>
# </div>
# <div class="white-desk ico-card" id="view_all"><a href="/category/active-ico/"><span>View all 34 Active ico</span><span><img src="/wp-content/themes/ico-drops-2-0/img/home_right.svg"/></span></a></div>
# </div>
# </div>
# <div class="col-12 col-lg-4">
# <div class="category-table-header">
# <h2><a href="https://icodrops.com/category/upcoming-ico/">UPCOMING ICO<sup class="blue">71</sup></a></h2>
# </div>
# <div class="ajax_content2" id="ajaxy">
# <div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="23004" href="https://icodrops.com/gatcoin/" id="ccc" rel="bookmark">
# <img alt="Gatcoin logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/Gatcoin-logo-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"> </img></a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/gatcoin/" rel="bookmark">GatCoin</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Marketing</div>
# <div class="goal-in-card">
# 				 GOAL: $14,500,000				</div>
# <div class="categ_desc_short">GATCOIN transforms traditional...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Marketing</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$14,500,000
# 			</div>
# <div class="date">
# 		14 Jan		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two yes tooltip" rel="Can’t participate: China" title="Can’t participate: China"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: 5% first week bonus" title="BONUS: 5% first week bonus"></div></div>
# </div><div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="15985" href="https://icodrops.com/aidcoin/" id="ccc" rel="bookmark">
# <img alt="" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/OHCpy0qj_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/aidcoin/" rel="bookmark">AidCoin</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Marketplace</div>
# <div class="goal-in-card">
# 				 GOAL: $39,200,000				</div>
# <div class="categ_desc_short">AidCoin is the token used...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Marketplace</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$39,200,000
# 			</div>
# <div class="date">
# 		16 Jan		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: NO INFORMATION" title="KYC: NO INFORMATION"></div><div class="categ_three no tooltip" rel="Whitelist: NO INFORMATION" title="Whitelist: NO INFORMATION"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: No" title="BONUS: No"></div></div>
# </div><div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="18366" href="https://icodrops.com/pre/experty/" id="ccc" rel="bookmark">
# <div class="pre-icon">PRE SALE</div> <img alt="Experty" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Experty-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/pre/experty/" rel="bookmark">Experty Pre-sale</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Blockchain Service</div>
# <div class="goal-in-card">
# 				 GOAL: $9,000,000				</div>
# <div class="categ_desc_short">Get paid crypto calls, anywhere...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Blockchain Service</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$9,000,000
# 			</div>
# <div class="date">
# 		22 Jan		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (UNTIL 01/15)" title="Whitelist: YES (UNTIL 01/15)"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA" title="Can’t participate: USA"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: 40% discount on Pre-sale" title="BONUS: 40% discount on Pre-sale"></div></div>
# </div><div class="white-desk ico-card pinned_ad">
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i> <div class="ico-row">
# <div class="ico-icon">
# <a data-id="5906" href="https://icodrops.com/wepower/" id="ccc" rel="bookmark">
# <img alt="WePower" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/10/WePower-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/wepower/" rel="bookmark">WePower</a>
# <i aria-hidden="true" class="fa fa-rocket" title="Advertising"></i>
# </h3>
# <div class="ico-category-name">Energy</div>
# <div class="goal-in-card">
# 				 GOAL: $35,000,000				</div>
# <div class="categ_desc_short">WePower is a blockchain-based...</div> </div>
# </div>
# <div class="interest">
# <span class="spspan">Sponsored</span> </div>
# <div class="categ_type">Energy</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$35,000,000
# 			</div>
# <div class="date">
# 		1 Feb		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA" title="Can’t participate: USA"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Review, Signature BT, Following" title="BOUNTY: Sharing, Translate, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 9%" title="BONUS: Up to 9%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="13939" href="https://icodrops.com/devery/" id="ccc" rel="bookmark">
# <img alt="Devery" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Devery-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/devery/" rel="bookmark">Devery</a>
# </h3>
# <div class="ico-category-name">Verification</div>
# <div class="goal-in-card">
# 				 GOAL: $10,000,000				</div>
# <div class="categ_desc_short">The Devery platform allows...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Verification</div>
# <div id="new_column_categ_invisted">
# <span class="notset">Pending</span>
# </div>
# <div id="categ_desctop">
# 			$10,000,000
# 			</div>
# <div class="date">
# 		12 Jan		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Following"></div><div class="categ_five yes tooltip" rel="BONUS: 5% discount on Pre-sale" title="BONUS: 5% discount on Pre-sale"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="14759" href="https://icodrops.com/selfkey/" id="ccc" rel="bookmark">
# <img alt="Selfkey" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Selfkey-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/selfkey/" rel="bookmark">Selfkey</a>
# </h3>
# <div class="ico-category-name">Verification</div>
# <div class="goal-in-card">
# <span class="green">
# 	$15,840,000	</span>
# 	/ $21,800,000 <span class="wat">73%</span> </div>
# <div class="categ_desc_short">SelfKey is a blockchain based...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Medium				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span><span class="nodoted"></span> </div> </div>
# <div class="categ_type">Verification</div>
# <div id="new_column_categ_invisted">
# <span>$15,840,000</span> <span class="prec">73%</span>
# </div>
# <div id="categ_desctop">
# 							$21,800,000
# 			</div>
# <div class="date">
# 		14 Jan		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two yes tooltip" rel="Can’t participate: USA, China, New Zealand" title="Can’t participate: USA, China, New Zealand"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: 30% during the pre-sale" title="BONUS: 30% during the pre-sale"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="17175" href="https://icodrops.com/coinfi/" id="ccc" rel="bookmark">
# <img alt="CoinFi logo" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/12/fh2_q976_400x400-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/coinfi/" rel="bookmark">CoinFi</a>
# </h3>
# <div class="ico-category-name">Trading</div>
# <div class="goal-in-card">
# 				 GOAL: $15,000,000				</div>
# <div class="categ_desc_short">CoinFi offers crowdsourced...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				High				</div>
# <div class="categ_dots"> <span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="doted"></span><span class="nodoted"></span> </div> </div>
# ...
# <div class="categ_type">Security</div>
# <div id="new_column_categ_invisted">
# <span>$14,681,250</span> <span class="prec">117%</span>
# </div>
# <div id="categ_desctop">
# 							$12,500,000
# 			</div>
# <div class="date">
# 		Ended: 29 Dec		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Signature BT, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 20%" title="BONUS: Up to 20%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="13052" href="https://icodrops.com/bitdegree/" id="ccc" rel="bookmark">
# <img alt="BitDegree" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/BitGegree-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/bitdegree/" rel="bookmark">BitDegree</a>
# </h3>
# <div class="ico-category-name">Marketplace</div>
# <div class="goal-in-card">
# <span class="green">
# 	$22,127,834	</span>
# 	/ $21,600,000 <span class="wat">102%</span> </div>
# <div class="categ_desc_short">The world's first blockchain-powered...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Marketplace</div>
# <div id="new_column_categ_invisted">
# <span>$22,127,834</span> <span class="prec">102%</span>
# </div>
# <div id="categ_desctop">
# 							$21,600,000
# 			</div>
# <div class="date">
# 		Ended: 28 Dec		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three no tooltip" rel="Whitelist: NO" title="Whitelist: NO"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Signature BT, Following, Bug Bounty" title="BOUNTY: Sharing, Translate, Guest Post, Review, Signature BT, Following, Bug Bounty"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 15% (first week)" title="BONUS: Up to 15% (first week)"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="13638" href="https://icodrops.com/canya/" id="ccc" rel="bookmark">
# <img alt="CanYa" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/CanYa-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/canya/" rel="bookmark">CanYa</a>
# </h3>
# <div class="ico-category-name">Marketplace</div>
# <div class="goal-in-card">
# <span class="green">
# 	$8,336,405	</span>
# 	/ $23,000,000 <span class="wat">36%</span> </div>
# <div class="categ_desc_short">CanYa is a peer to peer marketplace...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Marketplace</div>
# <div id="new_column_categ_invisted">
# <span>$8,336,405</span> <span class="prec">36%</span>
# </div>
# <div id="categ_desctop">
# 							$23,000,000
# 			</div>
# <div class="date">
# 		Ended: 27 Dec		</div>
# <div class="meta_icon">
# <div class="categ_one yes tooltip" rel="KYC: Yes" title="KYC: Yes"></div><div class="categ_three yes tooltip" id="linkwhitelist" rel="Whitelist: YES (PERIOD ISN’T SET)" title="Whitelist: YES (PERIOD ISN’T SET)"></div><div class="categ_two no tooltip" rel="CAN’T PARTICIPATE: NO INFORMATION" title="CAN’T PARTICIPATE: NO INFORMATION"></div><div class="categ_four yes tooltip" rel="Sharing, Translate, Guest Post, Review, Signature BT, Following" title="BOUNTY: Sharing, Translate, Guest Post, Review, Signature BT, Following"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 40%" title="BONUS: Up to 40%"></div></div>
# </div><div class="white-desk ico-card ">
# <div class="ico-row">
# <div class="ico-icon">
# <a data-id="13667" href="https://icodrops.com/sirin-labs/" id="ccc" rel="bookmark">
# <img alt="Sirin Labs" class="lazy-hidden attachment-thumbnail size-thumbnail wp-post-image" data-lazy-type="image" data-src="https://cdn.icodrops.com/wp-content/uploads/2017/11/Sirin-Labs-150x150.jpg" height="150" src="//icodrops.com/wp-content/plugins/a3-lazy-load/assets/images/lazy_placeholder.gif" width="150"/> </a>
# </div>
# <div class="ico-main-info">
# <h3><a href="https://icodrops.com/sirin-labs/" rel="bookmark">Sirin Labs</a>
# </h3>
# <div class="ico-category-name">Hi-Tech</div>
# <div class="goal-in-card">
# <span class="green">
# 	$157,885,825	</span>
# 	RECEIVED				</div>
# <div class="categ_desc_short">SIRIN LABS - the developer...</div> </div>
# </div>
# <div class="interest">
# <div class="all_site_val">
# 				Neutral				</div>
# <div class="categ_dots"> </div> </div>
# <div class="categ_type">Hi-Tech</div>
# <div id="new_column_categ_invisted">
# <span>$157,885,825</span>
# </div>
# <div id="categ_desctop">
# <span class="notset">Not Set</span>
# </div>
# <div class="date">
# 		Ended: 26 Dec		</div>
# <div class="meta_icon">
# <div class="categ_one no tooltip" rel="KYC: No" title="KYC: No"></div><div class="categ_three no tooltip" rel="Whitelist: NO" title="Whitelist: NO"></div><div class="categ_two no tooltip" rel="NO RESTRICTIONS" title="NO RESTRICTIONS"></div><div class="categ_four no tooltip" rel="BOUNTY: NO INFORMATION" title="BOUNTY: NO INFORMATION"></div><div class="categ_five yes tooltip" rel="BONUS: Up to 100% bonus tokens" title="BONUS: Up to 100% bonus tokens"></div></div>
# </div> <div class="white-desk ico-card" id="view_all"><a href="/category/ended-ico/"><span>View all 251 ENDED ico</span><span><img src="/wp-content/themes/ico-drops-2-0/img/home_right.svg"/></span></a></div>
# </div>
# </div>
# </div>
# </article><!-- #post-7 --> </div>
# </main><!-- #main -->
# </div><!-- #primary -->
# </div><!-- #content -->
# <footer class="new-site-footer" id="colophon">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <div class="new_footer_wrap">
# <div class="new_footer_col_one">
# <div class="new_footer_logo"><a href="/"><img alt="ICO Drops - Calendar of active and upcoming ICO" src="/wp-content/themes/ico-drops-2-0/img/footerlogo.svg"/></a></div>
# <div class="new_footer_copyright">
# <p>Made with <i aria-hidden="true" class="fa fa-heart"></i> for the Decentralized World.</p>
# <p class="desc_footer_ico">ICO Drops is an independent ICO (Token Sale) database and is not affiliated with any ICO project or company. Our "Interest Level" isn't a financial or investment advice.</p>
# </div></div></div></div></div></div></footer></div></body></html>
# <p>© 2018 ICO Drops. </p>
#
#
# <div class="new_footer_col_two">
# <div class="menu-menu-footer-one-container"><ul class="menu" id="menu-menu-footer-one"><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7535" id="menu-item-7535"><a href="https://icodrops.com/category/active-ico/">Active ICO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7536" id="menu-item-7536"><a href="https://icodrops.com/category/upcoming-ico/">Upcoming ICO</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-7537" id="menu-item-7537"><a href="https://icodrops.com/category/ended-ico/">Ended ICO</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7557" id="menu-item-7557"><a href="https://icodrops.com/bounty-list/">Bounty List</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21258" id="menu-item-21258"><a href="https://icodrops.com/sandbox/">Sandbox (Beta)</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21259" id="menu-item-21259"><a href="https://icodrops.com/whitelist/">Whitelist (Beta)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-21270" id="menu-item-21270"><a href="https://tools.icodrops.com/social/telegram" target="_blank">ICO Social (Beta)</a></li>
# </ul></div> </div>
# <div class="new_footer_col_three">
# <div class="menu-menu-footer-two-container"><ul class="menu" id="menu-menu-footer-two"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7541" id="menu-item-7541"><a href="https://icodrops.com/calendar/">ICO Calendar</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7543" id="menu-item-7543"><a href="http://eepurl.com/c09mS1">Newsletter</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7577" id="menu-item-7577"><a href="https://icodrops.com/submit-ico/">Submit ICO</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7558" id="menu-item-7558"><a href="https://icodrops.com/advertising-programm/">Advertising</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7544" id="menu-item-7544"><a href="https://icodrops.com/about/">About</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21260" id="menu-item-21260"><a href="https://icodrops.com/legal/">Legal</a></li>
# </ul></div>
# </div>
# <div class="new_footer_col_four">
# <div class="menu-menu-footer-three-container"><ul class="menu" id="menu-menu-footer-three"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7548" id="menu-item-7548"><a href="mailto:icodrops@gmail.com" target="_blank">Email</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7549" id="menu-item-7549"><a href="https://twitter.com/ICODrops" target="_blank">Twitter</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7550" id="menu-item-7550"><a href="https://t.me/icodrops" target="_blank">Telegram</a></li>
# </ul></div> </div>
#
#
#
#
# <!-- #colophon -->
# <!-- #page -->
# <link href="https://fonts.googleapis.com/css?family=Bitter|Lato|Libre+Baskerville|Montserrat|Neuton|Open+Sans|Pacifico|Raleway|Roboto|Sacramento|Varela+Round|Lato|Open Sans|Libre Baskerville|Montserrat|Neuton|Raleway|Roboto|Sacramento|Varela Round|Pacifico|Bitter" id="cp-google-fonts" rel="stylesheet" type="text/css"/>
# <input id="cp-push-down-support" type="hidden" value=""/>
# <input id="cp-top-offset-container" type="hidden" value=""/>
# <div class="cp-module cp-info-bar-border cp-info-bar cp-weekly-article cp-info-bar-container cp-ib-onload cp-clear cp-pos-bottom content-5a555921a2b51 cp_id_32cab cp_id_32cab global_info_bar_container ib-fixed smile-animated smile-slideInUp " data-after-content-value="50" data-animate-push-page="1" data-class="content-5a555921a2b51" data-closed-cookie-time="15" data-conversion-cookie-time="90" data-custom-class=" cp_id_32cab" data-dev-mode="disabled" data-entry-animation="smile-slideInUp" data-exit-animation="smile-slideOutDown" data-exit-intent="disabled" data-form-action="disappear" data-form-action-time="4" data-info_bar-id="cp_id_32cab" data-info_bar-style="cp_id_32cab" data-load-on-refresh="enabled" data-onload-delay="" data-onscroll-value="30" data-option="smile_info_bar_styles" data-push-down="0" data-referrer-check="hide" data-referrer-domain="" data-scheduled="false" data-timezone="Europe/Moscow" data-timezonename="" data-toggle="" data-tz-offset="3" id="cp-cp_id_32cab" style="min-height:41px;">
# <div class="cp-info-bar-wrapper cp-clear">
# <div class="cp-info-bar-body-overlay"></div>
# <div class="cp-flex cp-info-bar-body ib-close-outside" data-height="" style="min-height:41px;">
# <div class="cp-flex cp-ib-container">
# <input class="cp-impress-nonce" name="cp-impress-nonce" type="hidden" value="74790256ec"/>
# <div class="cp-image-container">
# <img class="cp-image cp_ifb_hide_img" src="https://cdn.icodrops.com/wp-content/uploads/2017/08/MailLogo.png" style="max-width:35px;width:35px;"/>
# </div> <div class="cp-msg-container ">
# <span class="cp-info-bar-msg"><span style="font-family:arial;"><span style="color:#000000;">Get the week’s best ICO right in your inbox</span></span></span>
# </div>
# <div class="cp-flex cp-sub-container">
# <div class="cp-form-container">
# <div class="form-main cp-form-layout-3">
# <form class="cp-form " id="smile-optin-form">
# <input id="_wpnonce" name="_wpnonce" type="hidden" value="b228742243"><input name="_wp_http_referer" type="hidden" value="/"> <input name="cp-page-url" type="hidden" value="https://icodrops.com">
# <input name="param[user_id]" type="hidden" value="cp-uid-18cea0b415f322b6654ca438ca14d12a"/>
# <input name="param[date]" type="hidden" value="10-1-2018"/>
# <input name="list_parent_index" type="hidden" value="1"/>
# <input name="action" type="hidden" value="mailchimp_add_subscriber"/>
# <input name="list_id" type="hidden" value="00588e7766"/>
# <input name="style_id" type="hidden" value="cp_id_32cab"/>
# <input name="msg_wrong_email" type="hidden" value="Please enter correct email address."/>
# <input name="message" type="hidden" value="Thank you 🙏 "/>
# <div class="cp-all-inputs-wrap col-xs-12 col-xs-12 col-sm-6 col-md-6 col-lg-6 ">
# <div class="cp-form-field col-md-12 col-lg-12 col-sm-12 col-xs-12 "><label>Email</label><div>
# <input class="cp-input cp-email" name="param[email]" placeholder="Your Email" required="" type="email"/> </div></div><!-- .cp-form-field -->
# </div>
# <div class="cp-submit-wrap cp-submit-wrap-full col-xs-12 col-sm-6 col-md-6 col-lg-6 ">
# <div ;="" class="cp-submit btn-subscribe cp_responsive cp-btn-flat smile-animated " data-animation="smile-none">
# 					                Subscribe					        </div>
# </div><!-- .cp-submit-wrap -->
# </input></input></input></form><!-- #smile-optin-form -->
# </div>
# </div>
# <div class="cp-flex cp-info-bar-desc-container cp-empty">
# <div class="cp-info-bar-desc"></div>
# </div>
# </div>
# </div><!-- cp-ib-container -->
# </div><!-- cp-info-bar-body -->
# </div>
# <!--toggle button-->
# <div class="ib-close ib-img-close cp-adjacent-right" style=" width:22px;"><img class="ib-img-default" close-link="" src="https://cdn.icodrops.com/wp-content/plugins/convertplug/modules/info_bar/functions/config/img/cross.png"/></div>
# <div class="cp-form-processing-wrap" style="position: absolute; display:none; ">
# <div class="cp-form-after-submit" style="line-height:41px;">
# <div class="cp-form-processing">
# <div class="smile-absolute-loader" style="visibility: visible;">
# <div class="smile-loader" style="width: 100px;">
# <div class="smile-loading-bar"></div>
# <div class="smile-loading-bar"></div>
# <div class="smile-loading-bar"></div>
# <div class="smile-loading-bar"></div>
# </div>
# </div>
# </div>
# <div class="cp-msg-on-submit" style="color:#000000;"></div>
# </div>
# </div>
# </div>
# <a class="cd-top" href="#0"><i aria-hidden="true" class="fa fa-angle-up"></i></a>
# <script defer="" src="https://cdn.icodrops.com/wp-content/cache/autoptimize/js/autoptimize_93ecf113e393324fadb8d6d011ee1427.js" type="text/javascript"></script>
# <!-- Yandex.Metrika counter -->
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/45725799" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
#
# <!-- Dynamic page generated in 0.887 seconds. -->
# <!-- Cached page generated by WP-Super-Cache on 2018-01-10 03:06:57 -->
# <!-- Compression = gzip -->

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://t.me/joinchat/FoisO0k4-XXBkPEikfdgow
# https://t.me/joinchat/FoisO0k4-XXBkPEikfdgow
# https://icodrops.com/ico-stats/
# https://icodrops.com/bounty-list/
# https://icodrops.com/category/ended-ico/
# https://icodrops.com/category/upcoming-ico/
# https://icodrops.com/category/active-ico/
# /
# /disclaimer/
# https://t.me/icodrops
# https://twitter.com/ICODrops
# https://icodrops.com/category/active-ico/
# https://icodrops.com/hoqu/
# https://icodrops.com/hoqu/
# https://icodrops.com/crowd-genie/
# https://icodrops.com/crowd-genie/
# https://icodrops.com/pre/apex/
# https://icodrops.com/pre/apex/
# https://icodrops.com/swissborg/
# https://icodrops.com/swissborg/
# https://icodrops.com/block-array/
# https://icodrops.com/block-array/
# https://icodrops.com/envion/
# https://icodrops.com/envion/
# https://icodrops.com/elastos/
# https://icodrops.com/elastos/
# https://icodrops.com/pre/fortknoxster-pre-sale/
# https://icodrops.com/pre/fortknoxster-pre-sale/
# https://icodrops.com/lala-world/
# https://icodrops.com/lala-world/
# https://icodrops.com/bankera/
# https://icodrops.com/bankera/
# https://icodrops.com/latium/
# https://icodrops.com/latium/
# https://icodrops.com/mobius/
# https://icodrops.com/mobius/
# https://icodrops.com/iungo/
# https://icodrops.com/iungo/
# https://icodrops.com/pareto/
# https://icodrops.com/pareto/
# https://icodrops.com/srg/
# https://icodrops.com/srg/
# /category/active-ico/
# https://icodrops.com/category/upcoming-ico/
# https://icodrops.com/gatcoin/
# https://icodrops.com/gatcoin/
# https://icodrops.com/aidcoin/
# https://icodrops.com/aidcoin/
# https://icodrops.com/pre/experty/
# https://icodrops.com/pre/experty/
# https://icodrops.com/wepower/
# https://icodrops.com/wepower/
# https://icodrops.com/devery/
# https://icodrops.com/devery/
# https://icodrops.com/selfkey/
# https://icodrops.com/selfkey/
# https://icodrops.com/coinfi/
# https://icodrops.com/coinfi/
# https://icodrops.com/insurepal/
# https://icodrops.com/insurepal/
# https://icodrops.com/bluzelle/
# https://icodrops.com/bluzelle/
# https://icodrops.com/zeepin/
# https://icodrops.com/zeepin/
# https://icodrops.com/pundi-x/
# https://icodrops.com/pundi-x/
# https://icodrops.com/dadi/
# https://icodrops.com/dadi/
# https://icodrops.com/origintrail/
# https://icodrops.com/origintrail/
# https://icodrops.com/apex/
# https://icodrops.com/apex/
# https://icodrops.com/experty/
# https://icodrops.com/experty/
# /category/upcoming-ico/
# https://icodrops.com/category/ended-ico/
# https://icodrops.com/ontology-network/
# https://icodrops.com/ontology-network/
# https://icodrops.com/neuromation/
# https://icodrops.com/neuromation/
# https://icodrops.com/crypterium/
# https://icodrops.com/crypterium/
# https://icodrops.com/theta-token/
# https://icodrops.com/theta-token/
# https://icodrops.com/zilliqa/
# https://icodrops.com/zilliqa/
# https://icodrops.com/trade-io/
# https://icodrops.com/trade-io/
# https://icodrops.com/pre/the-bee-token-pre-sale/
# https://icodrops.com/pre/the-bee-token-pre-sale/
# https://icodrops.com/bloom/
# https://icodrops.com/bloom/
# https://icodrops.com/covesting/
# https://icodrops.com/covesting/
# https://icodrops.com/telco/
# https://icodrops.com/telco/
# https://icodrops.com/stack/
# https://icodrops.com/stack/
# https://icodrops.com/gladius/
# https://icodrops.com/gladius/
# https://icodrops.com/bitdegree/
# https://icodrops.com/bitdegree/
# https://icodrops.com/canya/
# https://icodrops.com/canya/
# https://icodrops.com/sirin-labs/
# https://icodrops.com/sirin-labs/
# /category/ended-ico/
# /
# https://icodrops.com/category/active-ico/
# https://icodrops.com/category/upcoming-ico/
# https://icodrops.com/category/ended-ico/
# https://icodrops.com/bounty-list/
# https://icodrops.com/sandbox/
# https://icodrops.com/whitelist/
# https://tools.icodrops.com/social/telegram
# https://icodrops.com/calendar/
# http://eepurl.com/c09mS1
# https://icodrops.com/submit-ico/
# https://icodrops.com/advertising-programm/
# https://icodrops.com/about/
# https://icodrops.com/legal/
# mailto:icodrops@gmail.com
# https://twitter.com/ICODrops
# https://t.me/icodrops
# #0

# %%
#a = diagnose(soup)

# %%
import scrapy
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor

class GameDataSpider(CrawlSpider):
  name = "nfl_pbp_data"
  start_urls = ["http://www.pro-football-reference.com/years/2014/games.htm"]

  # the comma following the first item is REQUIRED for single rules
  rules = (
    Rule(LinkExtractor(allow=('boxscores/\w+\.htm')), callback='parse_game_data'),
  )

  def parse_game_data(self, response):
    # uses the filename as the game id that takes the form yyyymmdd0hometeam 
    # (i.e. 201409040sea) - purely a convenience choice
    game_id = response.url[response.url.rfind('/')+1:-4]
    date = game_id[:4] + '-' + game_id[4:6] + '-' + game_id[6:8]

    play_id = 1
    for row in response.xpath('//table[@id="pbp_data"]/tbody/tr[not(contains(@class,"thead"))]'):
      play = {}
      play['game_id'] = [game_id]
      play['date'] = [date]
      play['play_id'] = [play_id]
      play['quarter'] = row.xpath('td[1]//text()').extract()
      play['time'] = row.xpath('td[2]//text()').extract()
      play['down'] = row.xpath('td[3]//text()').extract()
      play['togo'] = row.xpath('td[4]//text()').extract()
      play['location'] = row.xpath('td[5]//text()').extract()
      play['detail'] = row.xpath('td[6]//text()').extract()
      play['away_points'] = row.xpath('td[7]//text()').extract()
      play['home_points'] = row.xpath('td[8]//text()').extract()
      play_id += 1

      # sanitize extracted data
      for key in play.keys():
        
        # no empty keys
        if not play[key]:
          play[key] = ''

        # join lists with multiple elements 
        elif len(play[key]) > 1:
          play[key] = ''.join(play[key])

        else:
          play[key] = play[key][0]
    
      # yield the item so that the scrapy engine can continue 
      # processing web requests concurrently
      yield play

# %%
scrapy crawl nfl_pbp_data -s DOWNLOAD_DELAY=5 --output_file=game_data.csv
# Out:
#   File "<ipython-input-62-cb73ebbb4347>", line 1
#     scrapy crawl nfl_pbp_data -s DOWNLOAD_DELAY=5 --output_file=game_data.csv
#                ^
# SyntaxError: invalid syntax
